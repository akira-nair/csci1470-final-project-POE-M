# %%
import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
import string
sns.set(rc = {"figure.dpi":300})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 from nltk.corpus import stopwords
#       5 import string
#       6 sns.set(rc = {"figure.dpi":300})
#
# ModuleNotFoundError: No module named 'nltk'

# %%
import pandas as pd

# %%
data = pd.read_csv("../data/haiku.csv")
data.shape
# Out:
# (15281, 5)

# %%
corpus = poem.get_corpus()

# %%
text = " ".join(corpus)

# %%
words = text.lower().split()

# %%
puncs = string.punctuation
puncs
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
stops = set(stopwords.words('english'))
words = [word for word in words if word not in stops and word not in puncs]

# %%
word_freq = {}
for word in words:
    if word in word_freq:
        word_freq[word]+=1
    else:
        word_freq[word]=0

# %%
sorted_word_freq = sorted(word_freq.items(), key=lambda x: x[1], reverse= True)
sorted_word_freq
# Out:
# [('love', 843),
#  ('like', 806),
#  ('one', 585),
#  ('time', 556),
#  ('life', 540),
#  ('im', 532),
#  ('haiku', 462),
#  ('day', 455),
#  ('still', 412),
#  ('dont', 411),
#  ('sun', 379),
#  ('heart', 372),
#  ('never', 346),
#  ('night', 343),
#  ('eyes', 336),
#  ('know', 320),
#  ('sky', 309),
#  ('away', 301),
#  ('leaves', 301),
#  ('new', 293),
#  ('rain', 293),
#  ('go', 291),
#  ('wind', 290),
#  ('back', 284),
#  ('cold', 284),
#  ('see', 279),
#  ('cant', 273),
#  ('light', 270),
#  ('words', 250),
#  ('us', 247),
#  ('summer', 246),
#  ('want', 245),
#  ('fall', 236),
#  ('feel', 234),
#  ('mind', 233),
#  ('world', 231),
#  ('always', 230),
#  ('good', 222),
#  ('get', 218),
#  ('old', 213),
#  ('two', 211),
#  ('lost', 210),
#  ('make', 207),
#  ('long', 206),
#  ('yet', 203),
#  ('please', 202),
#  ('alone', 202),
#  ('dark', 199),
#  ('hope', 197),
#  ('man', 197),
#  ('home', 197),
#  ('moon', 196),
#  ('last', 195),
#  ('clouds', 195),
#  ('winter', 190),
# ...

# %%
f, ax = plt.subplots(figsize = (8, 6))
sorted_word_freq = sorted_word_freq[:20]
words = [x[0] for x in sorted_word_freq]
freqs = [x[1] for x in sorted_word_freq]
ax=sns.barplot(x = freqs, y = words, orient = 'h', color = 'Teal')
